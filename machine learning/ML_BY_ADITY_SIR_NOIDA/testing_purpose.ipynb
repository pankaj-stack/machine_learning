# %%
import pandas as pd
df = pd.read_csv('Join_data_not_clean.csv')
df.shape
# Out:
# (398295, 86)

# %%
df.dtypes.value_counts()
# Out:
# float64    53
# object     20
# int64      13
# dtype: int64

# %%
object_df = df.select_dtypes(include='object')

# %%
object_df
# Out:
#        CIRCLE_NAME LAST_DATE_OF_MONTH DATE_OF_LAST_RECH  \
# 0               BH   31-07-2014 00:00  31-07-2014 00:00
# 1               BH   31-08-2014 00:00  30-08-2014 00:00
# 2               BH   30-09-2014 00:00  29-09-2014 00:00
# 3              KOL   30-06-2014 00:00  17-06-2014 00:00
# 4              KOL   31-07-2014 00:00  16-07-2014 00:00
# ...            ...                ...               ...
# 398290         ORI   31-08-2014 00:00  31-08-2014 00:00
# 398291         ORI   30-09-2014 00:00  30-09-2014 00:00
# 398292         KOL   30-06-2014 00:00  30-06-2014 00:00
# 398293         KOL   31-07-2014 00:00  29-07-2014 00:00
# 398294         KOL   31-08-2014 00:00  31-08-2014 00:00
#
#        DATE_OF_LAST_RECH_DATA  gender partner dependents phoneservice  \
# 0                         NaN    Male      No         No          Yes
# 1                         NaN    Male      No         No          Yes
# 2                         NaN    Male      No         No           No
# ...
