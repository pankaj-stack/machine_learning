# %% [raw]
# What is Boosting in Data Mining - Javatpoint
# There are three types of Algorithms available such as AdaBoost or Adaptive boosting Algorithm, Gradient, and XG Boosting algorithm.

# %% [raw]
# Ensemble learning me sabhi algorithm me ek kaam common hai vo ki week-models ka banana aur unhi weak
# models ki help se (ek strong model) ka banana aur usi strong models prediction krna

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # how boosting works

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 1.Provide training set to model-1
# 2.Provide training set  and misclassification samples of model-1 to model-2
# 3.Provide training set  and misclassification samples of model-2 to model-3 and so on.

# %% [markdown]
# ### adaboost means adaptive boosting

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier

# %%
df = pd.read_csv('/home/echelon/machine_learning_personal/machine learning/dataset/classification/iris.csv')
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values 
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=10)
# yhan pe n_estimators = 10 means ye maximum hain agar 5th estimator pe hi model 100% accurate ho gya to aage ke n_estimators nhi banenge
abc = AdaBoostClassifier(n_estimators=10) # by default DecisionTreeClassifier use krta hai aur iska depth hamesha 1 leke chalta hai
# yhan pe n_estimators means weak models by default 50 hote hain
abc.fit(X_train,y_train) 
print(f'Training Score : {abc.score(X_train,y_train)}')
print(f'Testing Score : {abc.score(X_test,y_test)}')
# Out:
# Training Score : 0.9553571428571429
# Testing Score : 0.9736842105263158

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# stump == DecisionTree with depth 1
# stumps == weak learner of DecisionTree with depth 1 is called stumps

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # working of adaboost algorithm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:980aac47-ad41-466b-9a03-71c13a629df2.png)

# %%
Adaboost jaise rashtra-pati chunav hota hota usi tarah se work krta (quality voting)

# %%
adaboosting dono batata hai probability and class.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### jinti bhi classification ki algorithm hai un sabhi ke corresponding regression algorithm hoti hain except LogisticRegression
