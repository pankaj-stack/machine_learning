# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # scatter graph:

# %% [raw]
# It provides understanding of data distribution between two variables
# or
# It shows relation between two variables

# %%
# plt.scatter(x,y)#x,y belongs to list/tuple/range/1d-array/series
plt.scatter([1,2,3,4,5],[3,5,20,6,7],c='blue')#Here we can write full name or
plt.scatter(range(1,6),range(1,6),c='r')#only the first letter of the color
plt.show()

# %%
import numpy as np
plt.scatter(range(1,6),range(1,6),c='c')#c=cyan
x=np.random.randint(1,10,5)
y=np.random.randint(1,10,5)
plt.scatter(x,y,c='y')#y=yellow
plt.show()

# %%
import pandas as pd
df=pd.read_csv('C:/Users/Dell/Downloads/archive/salary_predict_dataset.csv')

# %%
df
# Out:
#    experience  test_score  interview_score  Salary
# 0         NaN         8.0              8.0   50000
# 1         NaN         5.0              4.0   22000
# 2       three         6.0              5.0   30000
# 3        five         9.0              9.0   55000
# 4         six         3.0              5.0   13000
# 5         NaN         2.0              1.0    9000
# 6         ten         8.0              6.0   48000
# 7         one         1.0              2.0     500
# 8     fifteen         9.0              9.0   60000
# 9    thirteen         7.5              7.5   45000
# 10        ten         NaN              5.0   25000
# 11        NaN         1.0              1.0     500
# 12        one         3.0              6.0   25000
# 13       four         5.0              4.0   36000
# 14        six         5.0              NaN    8000
# 15     eleven         9.0              8.0   55000
# 16     twelve         9.0              9.0   58000
# ...

# %%
df['experience']=df.experience.map({'':0,'one':1,'two':2,'three':3,'four':4,'five':5,'six':6,'seven':7,'eight':8,'nine':9,'fifteen':15,'thirteen':13,'ten':10,'eleven':11,'twelve':12})
df.experience
# Out:
# 0      NaN
# 1      NaN
# 2      3.0
# 3      5.0
# 4      6.0
# 5      NaN
# 6     10.0
# 7      1.0
# 8     15.0
# 9     13.0
# 10    10.0
# 11     NaN
# 12     1.0
# 13     4.0
# 14     6.0
# 15    11.0
# 16    12.0
# 17     NaN
# 18     3.0
# 19     5.0
# Name: experience, dtype: float64

# %%
plt.scatter(df.experience,df.Salary,color='r',
            marker='d')#color can be written only 'c',d=diamond
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(df.experience,df.Salary,color='r',
            marker='o',edgecolor='black',s=90)#black can be written only 'k'
plt.xlabel('Experience')#s is responsible size of the marker
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(df.experience,df.Salary,color='r',
            marker='o',edgecolor='black',s=90)#black can be written only 'k'
plt.xlabel('Experience')#s is responsible size of the marker
plt.ylabel('Salary')
plt.title('Experience V/S Salary')#Text top of the figure
plt.text(4,10000,'Pankaj Jaiswal',c='g',size=10)
plt.show()

# %%
plt.scatter(df.experience,df.Salary,color='r',
            marker='o',edgecolor='black',s=90)
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Experience V/S Salary')
plt.text(4,10000,'Pankaj Jaiswal',c='g',size=10)
plt.grid()#<------------------------------------grid--------------------
plt.show()

# %%
plt.scatter(df.experience,df.Salary,color='r',
            marker='o',edgecolor='black',s=90)
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Experience V/S Salary')
plt.text(4,10000,'Pankaj Jaiswal',c='g',size=10)
plt.xticks(range(1,20))#To modify the x coordinates
plt.yticks(range(10000,150000,10000))#To modify the x coordinates
plt.show()

# %%
plt.scatter(df.experience,df.Salary,color='r',
            marker='o',edgecolor='black',s=90)
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Experience V/S Salary')
plt.text(4,10000,'Pankaj Jaiswal',c='g',size=10)
plt.xticks(range(1,20))
plt.yticks(range(10000,150000,10000))
plt.savefig('exp_sal.png')#To save the figure in the image format <--------
print('picture is saved in the current directory')
plt.show()
# Out:
# picture is saved in the current directory

# %% [raw]
# Line graph
# -----------
#     >It also shows  relations between two variables
#     >If one variable is changing over time and we need to visualise change
#         in other variable.

# %%
overs=[5,10,15,20]
run1=[40,90,120,160]
run2=[20,120,110,162]
plt.plot(overs,run1,c='y',marker='o')
plt.plot(overs,run2,c='b',marker='o')
plt.xlabel('Overs')
plt.ylabel('Runs')
plt.show()

# %%
overs=[5,10,15,20]
run1=[40,90,120,160]
run2=[20,120,110,162]
plt.plot(overs,run1,c='y',marker='o')
plt.plot(overs,run2,c='b',marker='o')
plt.xlabel('Overs')
plt.ylabel('Runs')
plt.legend(['Australia','India'])
plt.show()

# %%
date=['1 June','10 June','20 June','30 June','1 July','10 July','20 July','30 July']
cases=[200000,250000,350000,360000,300000,200000,10000,8000]
plt.plot(date,cases)
plt.xlabel('Date')
plt.ylabel('Cases')
plt.show()

# %% [raw]
# bar graph:
#     >It shows frequency of unique values of a variable.
#     >No.of males and females
#     >confirm cases in states1

# %%
import pandas
df=pd.read_csv('c:/aditya_sir_dataset/data_analysis/titanic.csv') 
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.gender
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: gender, Length: 891, dtype: object

# %%
df.gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
plt.bar(['male','female'],[100,250])
plt.show()

# %%
df.gender.value_counts()
# Out:
# male      577
# female    314
# Name: gender, dtype: int64

# %%
plt.bar(df.gender.unique(),df.gender.value_counts())
plt.show()

# %%
plt.bar(df.gender.unique(),df.gender.value_counts(),color=['r','b'],
        edgecolor='black')
plt.show()

# %%
df=pd.read_html('https://www.mohfw.gov.in/')#This website isn't working properly
df
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1239         """Send a complete request to the server."""
# -> 1240         self._send_request(method, url, body, headers, encode_chunked)
#    1241
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1285             body = _encode(body, 'body')
# -> 1286         self.endheaders(body, encode_chunked=encode_chunked)
#    1287
#
# ...

# %%
df[0]

# %% [markdown]
# # Histogram:
#     >It shows frequency in given ranges of a variable
#     >No. of employee within salary 10-15,15-20,20-20

# %%
df=pd.read_csv('c:/aditya_sir_dataset/data_analysis/titanic.csv')
df.shape
# Out:
# (891, 12)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
plt.hist(df.Age,bins=10,edgecolor='black')
plt.xticks(range(0,100,10))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [raw]
# pie chart:
#     >It shows part distribution of whole quantity
#     >Vote percentage/seats distribution to parties in a election

# %%
plt.pie(x=[50,20,2],labels=['A','B','C'])
plt.show()

# %%
plt.pie(x=[50,20,2],labels=['A','B','C'],autopct='%.1f',explode=(0,0,0.2))
plt.show()

# %% [markdown]
# # Lecture-2

# %%
import matplotlib.pyplot as plt
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.subplot(2,2,1)
plt.scatter(range(1,5),range(1,5))

plt.subplot(2,2,2)
plt.plot(range(1,5),range(1,5))

plt.subplot(2,2,3)
plt.bar(['male','female'],[100,10])

plt.subplot(2,2,4)
plt.pie([30,90,15],labels=['Java','Python','R'],autopct='%.1f')
plt.show()

# %% [raw]
# Seaborn:
#     >It is the extension of matplot.
#     >It makes very easy to plot graphs.
#     >We may also pass dataframe directly.
#     >It also adds some new type of plots----->
#                     >heatmap
#                     >pairplot
#                     >joinplot
#                     >etc...

# %%
import pandas as pd
df=pd.read_csv('c:/Users/Dell/Downloads/fruits.csv')
df
# Out:
#     diameter  weight FruitName
# 0        3.0      30    Banana
# 1        6.0     100     Apple
# 2        6.1      95     Apple
# 3        3.2      35    Banana
# 4        5.5      80     Apple
# 5        7.1     120    Banana
# 6        2.5      60    Banana
# 7        2.3     100    Banana
# 8        4.8      70     Apple
# 9        4.8      79     Apple
# 10       5.8     120     Apple
# 11       2.6      85    Banana
# 12       6.0     110     Apple
# 13       6.3      95     Apple
# 14       3.0      40    Banana
# 15       3.5      25    Banana
# 16       5.5     100     Apple
# 17       7.5     120     Apple
# 18       2.5      50    Banana
# 19       2.7      40    Banana
# 20       4.8      90     Apple
# 21       5.8      90     Apple

# %%
x=df.diameter
x
# Out:
# 0     3.0
# 1     6.0
# 2     6.1
# 3     3.2
# 4     5.5
# 5     7.1
# 6     2.5
# 7     2.3
# 8     4.8
# 9     4.8
# 10    5.8
# 11    2.6
# 12    6.0
# 13    6.3
# 14    3.0
# 15    3.5
# 16    5.5
# 17    7.5
# 18    2.5
# 19    2.7
# 20    4.8
# 21    5.8
# Name: diameter, dtype: float64

# %%
y=df.weight
y
# Out:
# 0      30
# 1     100
# 2      95
# 3      35
# 4      80
# 5     120
# 6      60
# 7     100
# 8      70
# 9      79
# 10    120
# 11     85
# 12    110
# 13     95
# 14     40
# 15     25
# 16    100
# 17    120
# 18     50
# 19     40
# 20     90
# 21     90
# Name: weight, dtype: int64

# %%
fruit_names=df.FruitName
fruit_names
# Out:
# 0     Banana
# 1      Apple
# 2      Apple
# 3     Banana
# 4      Apple
# 5     Banana
# 6     Banana
# 7     Banana
# 8      Apple
# 9      Apple
# 10     Apple
# 11    Banana
# 12     Apple
# 13     Apple
# 14    Banana
# 15    Banana
# 16     Apple
# 17     Apple
# 18    Banana
# 19    Banana
# 20     Apple
# 21     Apple
# Name: FruitName, dtype: object

# %%
fruit_names=df.FruitName.map({'Apple':'0','Banana':1})
fruit_names
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
# 5     1
# 6     1
# 7     1
# 8     0
# 9     0
# 10    0
# 11    1
# 12    0
# 13    0
# 14    1
# 15    1
# 16    0
# 17    0
# 18    1
# 19    1
# 20    0
# 21    0
# Name: FruitName, dtype: object

# %%
plt.scatter(x,y,c=f)
plt.xlabel('Diameter')
plt.ylabel('Weight')
plt.show()

# %%
import seaborn as sb

# %%
sb.scatterplot(x='diameter',y='weight',data=df,hue='FruitName')
plt.show()#hue means that more one things like 0 and 1

# %%
df=pd.read_csv('C:/aditya_sir_dataset/data_analysis/tips.csv')
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sb.lineplot(x='size',y='total_bill',data=df)
plt.show()

# %%
# sb.lineplot(x='size',y='total_bill',data=df,hue='gender')
# sb.lineplot(x='size',y='total_bill',data=df,hue='day')
sb.lineplot(x='size',y='total_bill',data=df,hue='time')

plt.show()

# %%
sb.barplot(x='day',y='total_bill',data=df)
plt.show()

# %%
# sb.barplot(x='day',y='total_bill',data=df,hue='gender')
sb.barplot(x='day',y='total_bill',data=df,hue='time')

plt.show()

# %%
sb.distplot(df.total_bill)
plt.show()

# %%
# sb.distplot(df.total_bill,kde='False')
sb.distplot(df.total_bill,kde='False',bins=10)#kenel density function(type of line plot that highlight density in data)
plt.show()

# %%
plt.figure(figsize=(10,8))
sb.jointplot(x='tip',y='total_bill',data=df)
plt.show()
#The upper portion of the graph is histogram of x.
#And right portion of the graph is histogram of y.

# %%
sb.pairplot(df)
plt.show()#figure 1,5 and 9 shows histogram for each numeric column present in dataframe
#figure 2,3 and 6 shows the scatter plots between each possible pair of numeric column.
#and fugure 4,7 and 8 are the mirror images of figure 1,5 and 9.

# %%
sb.pairplot(df,vars=['tip','total_bill'])
plt.show()

# %%
sb.pairplot(df,vars=['tip','total_bill'],hue='gender')
plt.show()

# %%
import numpy as np
arr=np.random.randint(1,5,(3,4))

# %%
sb.heatmap(arr)#It tries to explain anything with the help of color
plt.show()

# %%
sb.heatmap(arr,annot=True)#It tries to explain anything with the help of color
plt.show()

# %% [raw]
# heatmap is a good choice to understand correlation between two columns
# Example:
#     >shapoo and hair1

# %%
co_relation=df.corr()
co_relation
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sb.heatmap(co_relation)
plt.show()

# %% [raw]
# >The heatmap is a way of representing the data in a 2-D form.
# >The data values are represented as colors in the graph.
# >A heatmap contains values representing  various shades of the same color
#     for each.
# >Usually the darker shades fo the chart represented higher values than the
#     the lighter shades.
# >For a vary different value a completely different colour can also be used.

# %% [raw]
# Data Analysi:
#     >numpy
#     >pandas
#     >matplot
#     >seaborn
#     >docxpy
#     >slate3k
#     >webscrapping

# %% [raw]
# Structure Data:
#     >excel           ----->
#     >csv                 ----->                PANDAS is used in all these
#     >html table       -------->
#     >database table ----------- >
#
# Unstructured Data:
#     >pdf------------------------->pdfminer,pypdf,slate3k,etc
#     >word------------------------>docxy
#     >log------------------------->python file handling
#     >web page-------------------->beautifulsoup,scrapy,selenium etc
# >We have to use specific libraries for unstructured data.

# %%
pip install docxpy
# Out:
# ...
#   Created wheel for docxpy: filename=docxpy-0.8.5-py3-none-any.whl size=4985 sha256=19ac69321d904e93c03a2f393df48c9da9ac0bbb4ed914c080cf363f1b00c497
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\e5\f5\4b\ee4a91effc36ffdf859cb70cdb6821459aeee09296c5306b0a
# Successfully built docxpy
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#To uninstall=================>pip uninstall docxpy on the command prompt

# %%
import docxpy

# %%
text=docxpy.process('D:/Users/pankaj/Downloads/banking system synopsis.docx')
print(text)
# Out:
# Session(2020-2021)
#
#
#
#
#
# 				               MINI PROJECT
#
#
#
# Prepared by:
#
# Pankaj Jaiswal
#
#     Rollno:-2117620170039
#
# B.tech-CS (4th  yr)-7th sem
#
# Submitted to:
#
# Mr. Prateek Sir
#
#
#
# 1.Title of the project:
#
#   		                                 Lane  Lines Detection
#
#
#
# 2.Objective of the project:
#
# ...

# %%
type(text)
# Out:
# str

# %%
if input() in text:
    print('yes matched string is available in the doc file')
else:
    print('Not present int doc file')
# Out:
# Pankaj Jaiswal
# yes matched string is available in the doc file

# %%
pip install slate3k
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import slate3k
file=open('c:/Users/Dell/Downloads/REPORT.pdf','rb')#pdf file is binary file

# %%
pdf=slate3k.PDF(file)
print(f'Total no. of pages = {len(pdf)}')
print(pdf[0])
# Out:
# WARNING:pdfminer.layout:Too many boxes (436) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (123) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (741) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (907) to group, skipping.
# Total no. of pages = 47
# LOST AND FOUND MOBILE APPLICATION
#
# BY
#
# CS18-16
#
# Department of Computer Science
#
# School of Computing & Informatics Technology
#
# A Project Report Submitted to the
#
# School of Computing and Informatics Technology for the Study Leading to
#
# a Project Report
#
# in Partial Fulﬁlment of
#
# the requirements for the
#
# Award of
#
# the Degree of Bachelor of Science in
#
# Computer Science of Makerere University
#
# Supervisor:
#
# Mr. Emmanuel Lule
#
# Department of Computer Science
#
# School of Computing & Informatics Technology
#
# lule.emmanuel@cis.mak.ac.ug
#
# May, 2018

# %%
txt=pdf.text()
print(txt)
# Out:
# LOST AND FOUND MOBILE APPLICATION BY CS18-16 Department of Computer Science School of Computing & Informatics Technology A Project Report Submitted to the School of Computing and Informatics Technology for the Study Leading to a Project Report in Partial Fulﬁlment of the requirements for the Award of the Degree of Bachelor of Science in Computer Science of Makerere University Supervisor: Mr. Emmanuel Lule Department of Computer Science School of Computing & Informatics Technology lule.emmanuel@cis.mak.ac.ug May, 2018 Declaration We Group CS18-16 do hereby declare that this Pro ject Report is original and has not been published and/or submitted for any other degree award to any other University before. # Names Registration Number Signature 1 2 3 4 MUWONGE JULIUS 15/U/8595/PS KOMAKECH GEOFFREY 15/6687/PS LOKOSE FREZA WACA DAVID 15/U/21287 15/U/1722 Date: ———————————————————————————– Approval This Pro ject Report has been submitted for examination with the approval of the following supe
# ...

# %%
import os

# %%
print(help(os))
# Out:
# Help on module os:
#
# NAME
#     os - OS routines for NT or Posix depending on what system we're on.
#
# MODULE REFERENCE
#     https://docs.python.org/3.8/library/os
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This exports:
#       - all functions from posix or nt, e.g. unlink, stat, etc.
#       - os.path is either posixpath or ntpath
#       - os.name is either 'posix' or 'nt'
#       - os.curdir is a string representing the current directory (always '.')
#       - os.pardir is a string representing the parent directory (always '..')
#       - os.sep is the (or a most common) pathname separator ('/' or '\\')
#       - os.extsep is the extension separator (always '.')
# ...
