# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# df=pd.read_csv('/home/pankaj/Downloads/Market Fact.csv')
# df.head()
df=pd.read_csv('/home/pankaj/Downloads/Market Fact.csv')
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %% [markdown]
# ## Distplot

# %%
sns.distplot(df['Sales'])
plt.show()

# %%
sns.distplot(df['Profit'])

# %%
sns.distplot(df['Profit'],kde=False)# it is working like histogram
plt.show()##kde=kernal density estimater
# the graph is showing nor profit nor loss

# %%
df.shape
# Out:
# (8399, 10)

# %%
plt.hist(df['Profit'],edgecolor='red')
# plt.show()
# Out:
# (array([7.000e+00, 9.000e+00, 7.300e+01, 8.066e+03, 1.880e+02, 4.600e+01,
#         9.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([-14140.7  , -10004.561,  -5868.422,  -1732.283,   2403.856,
#           6539.995,  10676.134,  14812.273,  18948.412,  23084.551,
#          27220.69 ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(df['Profit'],kde=True)

# %%
sns.distplot(df['Profit'],kde=True,hist=False)#kde=kernal density estimater

# %% [markdown]
# # Subplot

# %%
#subplot
plt.subplots(2,2)#to plot no. of graphs on a single canvas<-----------subplots
plt.show()

# %%
# plt.subplot(2,2,1)
# sns.distplot(df['Sales'])#dist=distribution curve <------------displot
# plt.title('Sales')

# plt.subplot(2,2,2)
# sns.distplot(df['Profit'])#dist=distribution curve
# plt.title('Profit')

# plt.subplot(2,2,3)
# sns.distplot(df['Order_Quantity'])#dist=distribution curve
# plt.title('Order_Quantity')

# plt.subplot(2,2,4)
# sns.distplot(df['Shipping_Cost'])#dist=distribution curve
# plt.title('Shipping_Cost')
#----------------------OR---------------------------------------------
l=['Sales','Profit','Order_Quantity','Shipping_Cost']
for i in range(len(l)):
    plt.subplot(2,2,i+1)
    sns.distplot(df[l[i]])
    plt.title(i)

# %% [markdown]
# ## Box Plot

# %%
# sns.boxplot(df['Order_Quantity'])
# # plt.show()
sns.boxplot(df['Order_Quantity'])
plt.show()

# %%
# sns.boxplot(y=df['Order_Quantity'])
# plt.show()
sns.boxplot(y=df['Order_Quantity'])
plt.show()

# %% [markdown]
# ## Pair PLot

# %%
#pair plot is the extension of scatter plot
# pair=df[['Sales','Profit','Shipping_Cost']]

# %%
# sns.pairplot(pair)
# plt.show()
sns.pairplot(df[['Sales','Profit','Shipping_Cost']])
plt.show()

# %%
# co_relation_matrix=pair.corr()
# co_relation_matrix
co_relation_matrix=pair.corr()
co_relation_matrix

## Heat Map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-acdb1f816171> in <module>
#       1 # co_relation_matrix=pair.corr()
#       2 # co_relation_matrix
# ----> 3 co_relation_matrix=pair.corr()
#       4 co_relation_matrix
#       5
#
# NameError: name 'pair' is not defined

# %%
# sns.heatmap(co_relation_matrix)
# plt.show()
sns.heatmap(co_relation_matrix)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f307e77a73ff> in <module>
#       1 # sns.heatmap(co_relation_matrix)
#       2 # plt.show()
# ----> 3 sns.heatmap(co_relation_matrix)
#       4 plt.show()
#
# NameError: name 'co_relation_matrix' is not defined

# %%
sns.heatmap(co_relation_matrix,annot=True,cmap='autumn')#cmap is the color
plt.show()                                              #summer,winter,hot,cool,spring
                                                        #autumn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-eb3f6b887180> in <module>
# ----> 1 sns.heatmap(co_relation_matrix,annot=True,cmap='autumn')#cmap is the color
#       2 plt.show()                                              #summer,winter,hot,cool,spring
#       3                                                         #autumn
#
# NameError: name 'co_relation_matrix' is not defined

# %%
# Distribution curve <----------------Read  all these topics 
# Skewness 
# random graphs in numpy
#mean,median,
