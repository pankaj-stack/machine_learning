# %%
from matplotlib import pyplot as plt
x=[2015,2016,2017,2018,2019,2020]
y=[58000,68542,54000,84000,90000,42000]
plt.plot(x,y,label='Sales of Coke',linewidth=1)
plt.xlabel('year')
plt.ylabel('No of Unit Sales')
plt.xticks(x)
plt.yticks(y)
plt.legend()
plt.show()
